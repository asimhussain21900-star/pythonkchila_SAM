# %% [markdown]
# # Import libraries
# ## - Seaborn automatically installs these libraries
# - Numpy
# - scipy
# - pandas
# - matplotlib

# %%
#import libraries
import seaborn as sns
import matplotlib.pyplot as plt

# load data set

phool=sns.load_dataset("iris")
# phool

# draw a line port
sns.lineplot(x="sepal_length",y="sepal_width", data=phool)
plt.show()

# %%
# adding titles

# %%
#import libraries
import seaborn as sns
import matplotlib.pyplot as plt

# load data set

phool=sns.load_dataset("iris")
# phool

# draw a line port
sns.lineplot(x="sepal_length",y="sepal_width", data=phool)
plt.title("phoolon k plot")
plt.show()

# %%
# adding limits to x-axis and y-axis

# %%
#import libraries
import seaborn as sns
import matplotlib.pyplot as plt

# load data set

phool=sns.load_dataset("iris")
# phool

# draw a line port
sns.lineplot(x="sepal_length",y="sepal_width", data=phool)
plt.title("phoolon k plot")
plt.xlim(2)
plt.ylim(1)
plt.show()

# %% [markdown]
# # formatting in styles of plot
# - darkgrid
# - white grid
# - dark
# - white
# - ticks

# %%
import seaborn as sns
import matplotlib.pyplot as plt
 
# load data set

phool=sns.load_dataset("iris")
# phool

# draw a line port
sns.lineplot(x="sepal_length",y="sepal_width", data=phool)
plt.title("phoolon k plot")
sns.set_style("dark")
sns.set_style(None , rc= None)
plt.show()

# %% [markdown]
# # Size of Figure

# %%
import seaborn as sns
import matplotlib.pyplot as plt 
# load data set

phool=sns.load_dataset("iris")
# phool
# change figure
# draw a line plot
plt.figure(figsize=(4,2))
sns.lineplot(x="sepal_length",y="sepal_width", data=phool)
plt.title("phoolon k plot")
sns.set_style("dark")
plt.show()
