# %%
#pip install plotly
# Out:
# Requirement already satisfied: plotly in c:\users\fadmin\anaconda3\lib\site-packages (6.3.0)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\fadmin\anaconda3\lib\site-packages (from plotly) (2.7.0)
# Requirement already satisfied: packaging in c:\users\fadmin\anaconda3\lib\site-packages (from plotly) (25.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# now you can play alot of plot with in here just by copying code from plotly graphics and putting your data into it

# %%
import plotly.express as px
import matplotlib.pyplot as plt
df = px.data.iris()
fig = px.scatter_3d(df, x='sepal_length', y='sepal_width', z='petal_width',
              color='species')
fig.show()

# %%
plt.savefig('plot.png')
