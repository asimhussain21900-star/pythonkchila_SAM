# %% [markdown]
# # -Indexing

# %%
a="samosa pakora"
a
# Out:
# 'samosa pakora'

# %%
a
# Out:
# 'samosa pakora'

# %%
# to measure the length of indecies
len(a)
# Out:
# 13

# %%
a[0]
# Out:
# 's'

# %%
a[1]
# Out:
# 'a'

# %%
a[13]
# it will give error since the indeces are 13 but its starting from 0
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 a[13]
#       2 # it will give error since the indeces are 13 but its starting from 0
#
# IndexError: string index out of range

# %%
a[0:5]
# Out:
# 'samos'

# %% [markdown]
# #the last element will be not added like 5 index will be not added

# %%
a[0:6]
# Out:
# 'samosa'

# %%
a[0:13]
# Out:
# 'samosa pakora'

# %%
a[-1]
# Out:
# 'a'

# %% [markdown]
# # with negative index the string will be started from right to left but the pattern of sentence will not be changed like

# %%
a[-6]
# Out:
# 'p'

# %%
a[-1:-6]
#nothing printed here because english can be written from left to right only like below
# Out:
# ''

# %%
a[-6:-1]
# Out:
# 'pakor'

# %%
# in the above example a is missing from pakora because last index cant be zero and if we write -1 it will eat last word so to calculate it
# use lenth of the string like
len(a)
# Out:
# 13

# %%
a[-6:13]
# Out:
# 'pakora'

# %% [markdown]
# ## string methods

# %%
food = "biryani"
food
# Out:
# 'biryani'

# %%
len(food)
# Out:
# 7

# %%
food[0:7]
# Out:
# 'Biryani'

# %%
food
# Out:
# 'biryani'

# %%
#capitalize the letters first word
food.capitalize()
# Out:
# 'Biryani'

# %%
# all string in uppercase letter
food.upper()
# Out:
# 'BIRYANI'

# %%
#all string in lower case letter
food.lower()
# Out:
# 'biryani'

# %%
#replacing string letter with another one
food.replace("b","sh")
# Out:
# 'shiryani'

# %%
#counting an alphabet used in string like how many time single world is used
name = "Asim is going to be the python king soon"
name
# Out:
# 'Asim is going to be the python king soon'

# %%
name.count("a")
# Out:
# 0

# %%
name.count("A")
# Out:
# 1

# %%
name.count("i")
# Out:
# 4

# %% [markdown]
# # -Finding and index number in a string

# %%
name = "Asim is going to be the python king soon"
name
# Out:
# 'Asim is going to be the python king soon'

# %%
name.find("g")
# Out:
# 8

# %%
name.find("ng")
# Out:
# 11

# %% [markdown]
# ### -Index splitting

# %%
food = " I love samosa , pakora , biryani , raita and karahi "
food
# Out:
# ' I love samosa , pakora , biryani , raita and karahi '

# %%
food.split(",") # strings are splitted into multiple strings
# Out:
# [' I love samosa ', ' pakora ', ' biryani ', ' raita and karahi ']

# %% [markdown]
# # -Basic Data Structure in Python

# %% [markdown]
# ### 1. Tuple
# ### 2. list
# ### 3. dictionary
# ### 4. Set

# %% [markdown]
# ## Tuples
# ### . ordered Collection of Elements
# ### . enclosed in round braces / parenthsis ()
# ### . Different kind of elements can be stored
# ### . Once element are stored can't be changed (Unmutateable)

# %%
tup1 = (1 , "python" , True , 2.5)
tup1
# Out:
# (1, 'python', True, 2.5)

# %%
# check the type of tuple
type(tup1)
# Out:
# tuple

# %% [markdown]
# - Indexing in tuple

# %%
tup1[1]
        tup1[0]
# Out:
# 'king'

# %%
tup1[0:4]
# Out:
# (1, 'python', True, 2.5)

# %%
tup1[0:3]
# Out:
# (1, 'python', True)

# %%
len(tup1)
# Out:
# 4

# %%
tup2 = (2 , "king" , False , 10.5)
tup2
# Out:
# (2, 'king', False, 10.5)

# %%
tup1 = (1 , "python" , True , 2.5)

# %%
# addition of tuple to concatenate two or more then two tuple
tup1 + tup2
# Out:
# (1, 'python', True, 2.5, 2, 'king', False, 10.5)

# %%
# multiplication of tuple to concatenate and repeat two or more then two tuple
tup1 *2 + tup2
# Out:
# (1, 'python', True, 2.5, 1, 'python', True, 2.5, 2, 'king', False, 10.5)

# %%
# minimum value of tuple eg
tup3 = (10,11,12,13,14,15,16,17,9,34,12)
tup3
# Out:
# (10, 11, 12, 13, 14, 15, 16, 17, 9, 34, 12)

# %%
min(tup3)
# Out:
# 9

# %%
# maximum value of tup3
max(tup3)
# Out:
# 34

# %%
tup3*2 # this will not make changes inside data it will make changes in the number of tuples
# Out:
# (10,
#  11,
#  12,
#  13,
#  14,
#  15,
#  16,
#  17,
#  9,
#  34,
#  12,
#  10,
#  11,
#  12,
#  13,
#  14,
#  15,
#  16,
#  17,
#  9,
#  34,
#  12)

# %%
tup3+2 # can be done because tuple data can be added with tuple not integer
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 tup3+2
#
# TypeError: can only concatenate tuple (not "int") to tuple

# %% [markdown]
# ---

# %% [markdown]
# ## LIST
#
# - Ordered collection of elements
# - enclosed in []
# - mutable values can be changed

# %%
list1 = [ 1, "python" , True]
list1
# Out:
# [1, 'python', True]

# %%
type(list1)
# Out:
# list

# %%
len(list1)
# Out:
# 3

# %%
list1[2]
# Out:
# True

# %%
list2 = [3 , 5 , 7 , "Asim" , "python" , 478 , 15.5, False]
list2
# Out:
# [3, 5, 7, 'Asim', 'python', 478, 15.5, False]

# %%
list1 + list2
# Out:
# [1, 'python', True, 3, 5, 7, 'Asim', 'python', 478, 15.5, False]

# %%
list1*2
# Out:
# [1, 'python', True, 1, 'python', True]

# %%
list1.reverse()
list1
# Out:
# [True, 'python', 1]

# %%
list1.append("king") # to add something to the list
list1
# Out:
# [True, 'python', 1, 'king', 'king']

# %%
list1.count(1)
# Out:
# 2

# %%
list1
# Out:
# [True, 'python', 1, 'king', 'king']

# %%
list1.count(1)
# Out:
# 2

# %%
list3 = [10,20,30,40,50,60,70,356,453,220]
list3
# Out:
# [10, 20, 30, 40, 50, 60, 70, 356, 453, 220]

# %%
len(list3)
# Out:
# 10

# %%
# sorting a listing function
list3.sort()

# %%
list3
# Out:
# [10, 20, 30, 40, 50, 60, 70, 220, 356, 453]

# %%
list3.sort()

# %%
list3
# Out:
# [10, 20, 30, 40, 50, 60, 70, 220, 356, 453]

# %% [markdown]
# # - 3.Dictionaries
# - Unordered collection of data
# - key and value
# - mutatable / values can be changed
# - curly braces or brackets {}

# %%
# Food and there prices
d1 = {"samosa":30, "pakora":100, "raita":20, "salad":50, "chickenrole":60}
d1
# Out:
# {'samosa': 30, 'pakora': 100, 'raita': 20, 'salad': 50, 'chickenrole': 60}

# %%
type(d1)
# Out:
# dict

# %%
# extrattion of data ie keys or values

# %%
d1.keys()
keys1 = d1.keys()
keys1
# Out:
# dict_keys(['samosa', 'pakora', 'raita', 'salad', 'chickenrole'])

# %%
d1.values()
values1 = d1.values()
values1
# Out:
# dict_values([30, 100, 20, 50, 60])

# %%
#adding new item in dictionary
d1["tikki"]=40
d1
# Out:
# {'samosa': 30,
#  'pakora': 100,
#  'raita': 20,
#  'salad': 50,
#  'chickenrole': 60,
#  'tikki': 40}

# %%
# value can be modified as well simply
d1["tikki"]=70
d1
# Out:
# {'samosa': 30,
#  'pakora': 100,
#  'raita': 20,
#  'salad': 50,
#  'chickenrole': 60,
#  'tikki': 70}

# %%
# in dictionary simple addition can not concatenate two dictionary need to use update function
d2= {"dates":50, "choclates":200, "sawayian":1000}
d1+d2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[134], line 3
#       1 # in dictionary simple addition can not concatenate two dictionary need to use update function
#       2 d2= {"dates":50, "choclates":200, "sawayian":1000}
# ----> 3 d1+d2
#
# TypeError: unsupported operand type(s) for +: 'dict' and 'dict'

# %%
d1.update(d2)

# %%
d1
# Out:
# {'samosa': 30,
#  'pakora': 100,
#  'raita': 20,
#  'salad': 50,
#  'chickenrole': 60,
#  'tikki': 70,
#  'dates': 50,
#  'choclates': 200,
#  'sawayian': 1000}

# %% [markdown]
# ## 4. SET
# - uordered and unindexed values
# - curly braces are used {}
# - no duplicates allowed

# %%
s1={1,2.2,5.2, "ammar", "codanics","faisalabad", True}
s1
# Out:
# {1, 2.2, 5.2, 'ammar', 'codanics', 'faisalabad'}

# %%
s1.add("ammar")
s1
# Out:
# {1, 2.2, 5.2, 'ammar', 'codanics', 'faisalabad'}

# %%
s1.add("ammar1")
s1
# Out:
# {1, 2.2, 5.2, 'ammar', 'ammar1', 'codanics', 'faisalabad'}

# %%
s1.remove("ammar1")
s1
# Out:
# {1, 2.2, 5.2, 'ammar', 'codanics', 'faisalabad'}
